# %%
from pathlib import Path
script_path = Path.cwd() / 'train_model_v5.py'
print(script_path)
# Out:
# c:\GitHubMain\GraduateWork\ml5\train_model_v5.py

# %%
namespace = {}
exec(script_path.read_text(encoding='utf-8'), namespace)
build_feature_table = namespace['build_feature_table']
train_model = namespace['train_model']

# %%
datasets_root = Path.cwd() / 'datasets'
print('Datasets root:', datasets_root)
df, audit = build_feature_table(datasets_root)
print('Rows:', len(df))
print('Unique datasets:', df['dataset_id'].nunique())
print('Новые признаки в датасете:', [c for c in df.columns if 'relative' in c or 'ratio' in c or 'log' in c or 'n_children' in c])
df.head()
# Out:
# Datasets root: c:\GitHubMain\GraduateWork\ml5\datasets
# Rows: 812
# Unique datasets: 30
# Новые признаки в датасете: []
#   dataset_id     node_id  target_bootstrap  branch_length     depth  \
# 0        dt1  dt1_node_0              45.4       0.008893  0.008893
# 1        dt1  dt1_node_1              99.9       0.043788  0.043788
# 2        dt1  dt1_node_2              30.4       0.002224  0.002224
# 3        dt1  dt1_node_3             100.0       0.033556  0.042448
# 4        dt1  dt1_node_4              42.4       0.004816  0.013709
#
#    n_leaves_subtree  subtree_fraction  subtree_balance  \
# 0              22.0           0.68750         0.000000
# 1               3.0           0.09375         0.333333
# 2               7.0           0.21875         0.428571
# 3              11.0           0.34375         0.636364
# 4              11.0           0.34375         0.818182
#
#    mean_child_branch_length  std_child_branch_length  taxa_count  \
# 0                  0.019186                 0.014370        32.0
# 1                  0.049395                 0.016235        32.0
# 2                  0.013116                 0.002767        32.0
# 3                  0.031143                 0.024793        32.0
# 4                  0.047516                 0.018597        32.0
#
#    alignment_length  gap_fraction_global  gc_mean_global  gc_std_global  \
# 0            2142.0             0.312544        0.517434        0.03728
# 1            2142.0             0.312544        0.517434        0.03728
# 2            2142.0             0.312544        0.517434        0.03728
# 3            2142.0             0.312544        0.517434        0.03728
# 4            2142.0             0.312544        0.517434        0.03728
#
#    variable_site_fraction_global  gap_fraction_clade  gc_mean_clade  \
# 0                       0.830099            0.329115       0.521565
# 1                       0.830099            0.250233       0.498934
# 2                       0.830099            0.283253       0.512382
# 3                       0.830099            0.306291       0.513912
# 4                       0.830099            0.351940       0.529217
#
#    gc_std_clade  mean_pairwise_pdist_clade
# 0      0.036721                   0.363910
# 1      0.035370                   0.116415
# 2      0.036787                   0.250606
# 3      0.037339                   0.444156
# 4      0.034432                   0.215477

# %%
import pandas as pd
pd.DataFrame(audit)
# Out:
#    dataset_id                                     alignment_file  \
# 0         dt1  c:\GitHubMain\GraduateWork\ml5\datasets\dt1\1_...
# 1        dt10  c:\GitHubMain\GraduateWork\ml5\datasets\dt10\M...
# 2        dt11  c:\GitHubMain\GraduateWork\ml5\datasets\dt11\M...
# 3        dt12  c:\GitHubMain\GraduateWork\ml5\datasets\dt12\M...
# 4        dt13  c:\GitHubMain\GraduateWork\ml5\datasets\dt13\M...
# 5        dt14  c:\GitHubMain\GraduateWork\ml5\datasets\dt14\M...
# 6        dt15  c:\GitHubMain\GraduateWork\ml5\datasets\dt15\M...
# 7        dt16  c:\GitHubMain\GraduateWork\ml5\datasets\dt16\M...
# 8        dt17  c:\GitHubMain\GraduateWork\ml5\datasets\dt17\M...
# 9        dt18  c:\GitHubMain\GraduateWork\ml5\datasets\dt18\M...
# 10       dt19  c:\GitHubMain\GraduateWork\ml5\datasets\dt19\M...
# 11        dt2  c:\GitHubMain\GraduateWork\ml5\datasets\dt2\M3...
# 12       dt20  c:\GitHubMain\GraduateWork\ml5\datasets\dt20\M...
# 13       dt21  c:\GitHubMain\GraduateWork\ml5\datasets\dt21\M...
# 14       dt22  c:\GitHubMain\GraduateWork\ml5\datasets\dt22\M...
# 15       dt23  c:\GitHubMain\GraduateWork\ml5\datasets\dt23\M...
# 16       dt24  c:\GitHubMain\GraduateWork\ml5\datasets\dt24\M...
# 17       dt25  c:\GitHubMain\GraduateWork\ml5\datasets\dt25\M...
# 18       dt26  c:\GitHubMain\GraduateWork\ml5\datasets\dt26\M...
# 19       dt27  c:\GitHubMain\GraduateWork\ml5\datasets\dt27\M...
# 20       dt28  c:\GitHubMain\GraduateWork\ml5\datasets\dt28\M...
# 21       dt29  c:\GitHubMain\GraduateWork\ml5\datasets\dt29\M...
# 22        dt3  c:\GitHubMain\GraduateWork\ml5\datasets\dt3\M1...
# 23       dt30  c:\GitHubMain\GraduateWork\ml5\datasets\dt30\M...
# 24        dt4  c:\GitHubMain\GraduateWork\ml5\datasets\dt4\M1...
# 25        dt5  c:\GitHubMain\GraduateWork\ml5\datasets\dt5\M2...
# 26        dt6  c:\GitHubMain\GraduateWork\ml5\datasets\dt6\M1...
# 27        dt7  c:\GitHubMain\GraduateWork\ml5\datasets\dt7\M3...
# 28        dt8  c:\GitHubMain\GraduateWork\ml5\datasets\dt8\1_...
# 29        dt9  c:\GitHubMain\GraduateWork\ml5\datasets\dt9\1_...
#
#                                             tree_file    ok error  n_rows
# 0   c:\GitHubMain\GraduateWork\ml5\datasets\dt1\Ne...  True  None      29
# 1   c:\GitHubMain\GraduateWork\ml5\datasets\dt10\N...  True  None      14
# 2   c:\GitHubMain\GraduateWork\ml5\datasets\dt11\N...  True  None      37
# 3   c:\GitHubMain\GraduateWork\ml5\datasets\dt12\N...  True  None      18
# 4   c:\GitHubMain\GraduateWork\ml5\datasets\dt13\N...  True  None      28
# 5   c:\GitHubMain\GraduateWork\ml5\datasets\dt14\N...  True  None      34
# 6   c:\GitHubMain\GraduateWork\ml5\datasets\dt15\N...  True  None      42
# 7   c:\GitHubMain\GraduateWork\ml5\datasets\dt16\N...  True  None      41
# 8   c:\GitHubMain\GraduateWork\ml5\datasets\dt17\N...  True  None      51
# 9   c:\GitHubMain\GraduateWork\ml5\datasets\dt18\N...  True  None       7
# 10  c:\GitHubMain\GraduateWork\ml5\datasets\dt19\N...  True  None      10
# 11  c:\GitHubMain\GraduateWork\ml5\datasets\dt2\Ne...  True  None      44
# 12  c:\GitHubMain\GraduateWork\ml5\datasets\dt20\N...  True  None      24
# 13  c:\GitHubMain\GraduateWork\ml5\datasets\dt21\N...  True  None      15
# 14  c:\GitHubMain\GraduateWork\ml5\datasets\dt22\N...  True  None      43
# 15  c:\GitHubMain\GraduateWork\ml5\datasets\dt23\N...  True  None      38
# 16  c:\GitHubMain\GraduateWork\ml5\datasets\dt24\N...  True  None      25
# 17  c:\GitHubMain\GraduateWork\ml5\datasets\dt25\N...  True  None      33
# 18  c:\GitHubMain\GraduateWork\ml5\datasets\dt26\N...  True  None       4
# 19  c:\GitHubMain\GraduateWork\ml5\datasets\dt27\N...  True  None       4
# 20  c:\GitHubMain\GraduateWork\ml5\datasets\dt28\N...  True  None      18
# 21  c:\GitHubMain\GraduateWork\ml5\datasets\dt29\N...  True  None      13
# 22  c:\GitHubMain\GraduateWork\ml5\datasets\dt3\Ne...  True  None      34
# 23  c:\GitHubMain\GraduateWork\ml5\datasets\dt30\N...  True  None      15
# 24  c:\GitHubMain\GraduateWork\ml5\datasets\dt4\Ne...  True  None      25
# 25  c:\GitHubMain\GraduateWork\ml5\datasets\dt5\Ne...  True  None      50
# 26  c:\GitHubMain\GraduateWork\ml5\datasets\dt6\Ne...  True  None      28
# 27  c:\GitHubMain\GraduateWork\ml5\datasets\dt7\Ne...  True  None      26
# 28  c:\GitHubMain\GraduateWork\ml5\datasets\dt8\Ne...  True  None      18
# 29  c:\GitHubMain\GraduateWork\ml5\datasets\dt9\Ne...  True  None      44

# %%
model, metrics, feature_importance, pred_df = train_model(df)

metrics

feature_importance.head(20)
# Out:
# [INFO] Запуск подбора гиперпараметров для Random Forest...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#                           feature  importance
# 0                   branch_length    0.531729
# 11                  gc_std_global    0.082334
# 5        mean_child_branch_length    0.051555
# 21                      deep_node    0.040233
# 1                           depth    0.037027
# 6         std_child_branch_length    0.033886
# 8                alignment_length    0.031814
# 2                n_leaves_subtree    0.029778
# 15                   gc_std_clade    0.027032
# 3                subtree_fraction    0.025638
# 9             gap_fraction_global    0.017375
# 17                          bl_cv    0.016540
# 12  variable_site_fraction_global    0.015312
# 4                 subtree_balance    0.012915
# 16      mean_pairwise_pdist_clade    0.010856
# 10                 gc_mean_global    0.009819
# 13             gap_fraction_clade    0.007849
# 14                  gc_mean_clade    0.006983
# 7                      taxa_count    0.005452
# 18                  gap_var_clade    0.003571

# %%
import json
import joblib
import pandas as pd
from pathlib import Path

output_dir = Path.cwd() / "ml_outputs_v1"
output_dir.mkdir(exist_ok=True)

df.to_csv(output_dir / "node_dataset.csv", index=False, encoding="utf-8-sig")
pd.DataFrame(audit).to_csv(output_dir / "dataset_audit.csv", index=False, encoding="utf-8-sig")
feature_importance.to_csv(output_dir / "feature_importance.csv", index=False, encoding="utf-8-sig")
pred_df.to_csv(output_dir / "test_predictions.csv", index=False, encoding="utf-8-sig")
joblib.dump(model, output_dir / "model_v5.pkl")

with open(output_dir / "model_metadata.json", "w", encoding="utf-8") as f:
    json.dump(metrics, f, ensure_ascii=False, indent=2)

print("Сохранено в:", output_dir)
# Out:
# Сохранено в: c:\GitHubMain\GraduateWork\ml5\ml_outputs_v1

# %%
print("Всего строк:", len(df))
print("Уникальных datasets:", df["dataset_id"].nunique())
print("Колонки:")
print(df.columns.tolist())
# Out:
# Всего строк: 812
# Уникальных datasets: 30
# Колонки:
# ['dataset_id', 'node_id', 'target_bootstrap', 'branch_length', 'depth', 'n_leaves_subtree', 'subtree_fraction', 'subtree_balance', 'mean_child_branch_length', 'std_child_branch_length', 'taxa_count', 'alignment_length', 'gap_fraction_global', 'gc_mean_global', 'gc_std_global', 'variable_site_fraction_global', 'gap_fraction_clade', 'gc_mean_clade', 'gc_std_clade', 'mean_pairwise_pdist_clade']

# %%
df["target_bootstrap"].describe()
# Out:
# count    812.000000
# mean      64.218227
# std       33.486942
# min        0.000000
# 25%       36.200000
# 50%       70.850000
# 75%       98.525000
# max      100.000000
# Name: target_bootstrap, dtype: float64

# %%
metrics
# Out:
# {'n_rows_total': 812,
#  'mae': 6.95260606774955,
#  'rmse': 9.412118890416368,
#  'r2': 0.9182445799465488,
#  'cv_r2_mean': 0.5497746091838971,
#  'best_params': {'max_depth': 32,
#   'max_features': 0.8,
#   'min_samples_leaf': 3,
#   'min_samples_split': 5,
#   'n_estimators': 802},
#  'pred_range': '5.5–100.0',
#  'feature_columns': ['branch_length',
#   'depth',
#   'n_leaves_subtree',
#   'subtree_fraction',
#   'subtree_balance',
#   'mean_child_branch_length',
#   'std_child_branch_length',
#   'taxa_count',
#   'alignment_length',
#   'gap_fraction_global',
#   'gc_mean_global',
#   'gc_std_global',
#   'variable_site_fraction_global',
#   'gap_fraction_clade',
#   'gc_mean_clade',
#   'gc_std_clade',
#   'mean_pairwise_pdist_clade',
#   'bl_cv',
#   'gap_var_clade',
#   'gc_extreme',
#   'tiny_clade',
#   'deep_node']}
