# %%
from pathlib import Path
script_path = Path.cwd() / 'train_model_v2_fix.py'
print(script_path)
# Out:
# c:\GitHubMain\GraduateWork\ml2\train_model_v2_fix.py

# %%
namespace = {}
exec(script_path.read_text(encoding='utf-8'), namespace)
build_feature_table = namespace['build_feature_table']
train_model = namespace['train_model']

# %%
datasets_root = Path.cwd() / 'datasets_iqtree'
print('Datasets root:', datasets_root)
df, audit = build_feature_table(datasets_root)
print('Rows:', len(df))
print('Datasets parsed:', df['dataset_id'].nunique())
df.head()
# Out:
# Datasets root: c:\GitHubMain\GraduateWork\ml2\datasets_iqtree
# Rows: 1120
# Datasets parsed: 33
#   dataset_id       node_id  target_bootstrap  branch_length     depth  \
# 0      dt001  dt001_node_0              63.0       0.051483  0.051483
# 1      dt001  dt001_node_1              72.0       0.029472  0.080956
# 2      dt001  dt001_node_2              97.0       0.049989  0.130944
# 3      dt001  dt001_node_3              64.0       0.017858  0.148802
# 4      dt001  dt001_node_4              89.0       0.021453  0.170255
#
#    n_leaves_subtree  subtree_fraction  subtree_balance  \
# 0              25.0              12.5         0.920000
# 1              24.0              12.0         0.916667
# 2              23.0              11.5         0.913043
# 3              22.0              11.0         0.090909
# 4              12.0               6.0         0.833333
#
#    mean_child_branch_length  std_child_branch_length  taxa_count  \
# 0                  0.058157                 0.028685         2.0
# 1                  0.050658                 0.000669         2.0
# 2                  0.029056                 0.011198         2.0
# 3                  0.021947                 0.000494         2.0
# 4                  0.010474                 0.010472         2.0
#
#    alignment_length  gap_fraction_global  gc_mean_global  gc_std_global  \
# 0               8.0               0.4375          0.5625         0.4375
# 1               8.0               0.4375          0.5625         0.4375
# 2               8.0               0.4375          0.5625         0.4375
# 3               8.0               0.4375          0.5625         0.4375
# 4               8.0               0.4375          0.5625         0.4375
#
#    variable_site_fraction_global  gap_fraction_clade  gc_mean_clade  \
# 0                            1.0                 NaN            NaN
# 1                            1.0                 NaN            NaN
# 2                            1.0                 NaN            NaN
# 3                            1.0                 NaN            NaN
# 4                            1.0                 NaN            NaN
#
#    gc_std_clade  mean_pairwise_pdist_clade
# 0           NaN                        NaN
# 1           NaN                        NaN
# 2           NaN                        NaN
# 3           NaN                        NaN
# 4           NaN                        NaN

# %%
import pandas as pd
pd.DataFrame(audit)
# Out:
#    dataset_id                                     alignment_file  \
# 0       dt001  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 1       dt002  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 2       dt003  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 3       dt004  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 4       dt005  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 5       dt007  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 6       dt008  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 7       dt009  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 8       dt010  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 9       dt011  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 10      dt012  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 11      dt015  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 12      dt017  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 13      dt018  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 14      dt019  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 15      dt020  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 16      dt021  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 17      dt022  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 18      dt023  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 19      dt024  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 20      dt025  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 21      dt026  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 22      dt027  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 23      dt028  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 24      dt030  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 25      dt031  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 26      dt032  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 27      dt033  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 28      dt034  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 29      dt035  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 30      dt036  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 31      dt037  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
# 32      dt038  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...
#
#                                             tree_file    ok error  n_rows
# 0   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      24
# 1   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None       8
# 2   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      34
# 3   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      25
# 4   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      51
# 5   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      37
# 6   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      37
# 7   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      60
# 8   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      14
# 9   c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      33
# 10  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      21
# 11  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      41
# 12  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      62
# 13  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      44
# 14  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      18
# 15  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      24
# 16  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      24
# 17  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      15
# 18  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      34
# 19  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      43
# 20  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      13
# 21  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      71
# 22  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      25
# 23  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      33
# 24  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      63
# 25  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      43
# 26  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      60
# 27  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      55
# 28  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None       4
# 29  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      22
# 30  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None      71
# 31  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None       4
# 32  c:\GitHubMain\GraduateWork\ml2\datasets_iqtree...  True  None       7

# %%
model, metrics, feature_importance, pred_df = train_model(df)

metrics

feature_importance.head(20)
# Out:
#                           feature  importance
# 0                   branch_length    0.482387
# 5        mean_child_branch_length    0.165096
# 6         std_child_branch_length    0.125903
# 1                           depth    0.074329
# 9             gap_fraction_global    0.036606
# 2                n_leaves_subtree    0.029716
# 4                 subtree_balance    0.029476
# 3                subtree_fraction    0.028387
# 11                  gc_std_global    0.011090
# 10                 gc_mean_global    0.010019
# 12  variable_site_fraction_global    0.006872
# 8                alignment_length    0.000119
# 7                      taxa_count    0.000000
# 13             gap_fraction_clade    0.000000
# 14                  gc_mean_clade    0.000000
# 15                   gc_std_clade    0.000000
# 16      mean_pairwise_pdist_clade    0.000000

# %%
import json
import joblib
import pandas as pd
from pathlib import Path

output_dir = Path.cwd() / "ml_outputs_v1"
output_dir.mkdir(exist_ok=True)

df.to_csv(output_dir / "node_dataset.csv", index=False, encoding="utf-8-sig")
pd.DataFrame(audit).to_csv(output_dir / "dataset_audit.csv", index=False, encoding="utf-8-sig")
feature_importance.to_csv(output_dir / "feature_importance.csv", index=False, encoding="utf-8-sig")
pred_df.to_csv(output_dir / "test_predictions.csv", index=False, encoding="utf-8-sig")
joblib.dump(model, output_dir / "model_v1.pkl")

with open(output_dir / "model_metadata.json", "w", encoding="utf-8") as f:
    json.dump(metrics, f, ensure_ascii=False, indent=2)

print("Сохранено в:", output_dir)
# Out:
# Сохранено в: c:\GitHubMain\GraduateWork\ml2\ml_outputs_v1

# %%
print("Всего строк:", len(df))
print("Уникальных datasets:", df["dataset_id"].nunique())
print("Колонки:")
print(df.columns.tolist())
# Out:
# Всего строк: 1120
# Уникальных datasets: 33
# Колонки:
# ['dataset_id', 'node_id', 'target_bootstrap', 'branch_length', 'depth', 'n_leaves_subtree', 'subtree_fraction', 'subtree_balance', 'mean_child_branch_length', 'std_child_branch_length', 'taxa_count', 'alignment_length', 'gap_fraction_global', 'gc_mean_global', 'gc_std_global', 'variable_site_fraction_global', 'gap_fraction_clade', 'gc_mean_clade', 'gc_std_clade', 'mean_pairwise_pdist_clade']

# %%
df["target_bootstrap"].describe()
# Out:
# count    1120.000000
# mean       67.383036
# std        29.080897
# min         2.000000
# 25%        45.000000
# 50%        71.000000
# 75%        97.000000
# max       100.000000
# Name: target_bootstrap, dtype: float64

# %%
metrics
# Out:
# {'n_rows_total': 1120,
#  'n_rows_train': 794,
#  'n_rows_test': 326,
#  'n_datasets_total': 33,
#  'n_datasets_train': 24,
#  'n_datasets_test': 9,
#  'mae': 20.84172801635992,
#  'rmse': 27.6250656009116,
#  'r2': 0.19216843385765847,
#  'feature_columns': ['branch_length',
#   'depth',
#   'n_leaves_subtree',
#   'subtree_fraction',
#   'subtree_balance',
#   'mean_child_branch_length',
#   'std_child_branch_length',
#   'taxa_count',
#   'alignment_length',
#   'gap_fraction_global',
#   'gc_mean_global',
#   'gc_std_global',
#   'variable_site_fraction_global',
#   'gap_fraction_clade',
#   'gc_mean_clade',
#   'gc_std_clade',
#   'mean_pairwise_pdist_clade'],
#  'train_datasets': ['dt001',
#   'dt002',
#   'dt003',
#   'dt004',
#   'dt005',
#   'dt007',
#   'dt008',
#   'dt009',
#   'dt012',
#   'dt015',
#   'dt018',
#   'dt019',
#   'dt021',
#   'dt023',
#   'dt025',
#   'dt027',
#   'dt028',
#   'dt030',
#   'dt031',
#   'dt033',
#   'dt034',
#   'dt035',
#   'dt036',
#   'dt038'],
#  'test_datasets': ['dt010',
#   'dt011',
#   'dt017',
#   'dt020',
#   'dt022',
#   'dt024',
#   'dt026',
#   'dt032',
#   'dt037']}
