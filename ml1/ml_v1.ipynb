# %%
from pathlib import Path
script_path = Path.cwd() / 'train_model_v1_fix.py'
print(script_path)
# Out:
# c:\GitHubMain\GraduateWork\ml_outputs_v1\train_model_v1_fix.py

# %%
namespace = {}
exec(script_path.read_text(encoding='utf-8'), namespace)
build_feature_table = namespace['build_feature_table']
train_model = namespace['train_model']

# %%
datasets_root = Path.cwd() / 'datasets'
print('Datasets root:', datasets_root)
df, audit = build_feature_table(datasets_root)
print('Rows:', len(df))
print('Datasets parsed:', df['dataset_id'].nunique())
df.head()
# Out:
# Datasets root: c:\GitHubMain\GraduateWork\ml_outputs_v1\datasets
# Rows: 730
# Datasets parsed: 14
#   dataset_id     node_id  target_bootstrap  branch_length     depth  \
# 0        dt1  dt1_node_0             41.67       0.008893  0.008893
# 1        dt1  dt1_node_1            100.00       0.043788  0.043788
# 2        dt1  dt1_node_2             32.00       0.002224  0.002224
# 3        dt1  dt1_node_3            100.00       0.033556  0.042448
# 4        dt1  dt1_node_4             45.00       0.004816  0.013709
#
#    n_leaves_subtree  subtree_fraction  subtree_balance  \
# 0              22.0           0.68750         0.000000
# 1               3.0           0.09375         0.333333
# 2               7.0           0.21875         0.428571
# 3              11.0           0.34375         0.636364
# 4              11.0           0.34375         0.818182
#
#    mean_child_branch_length  std_child_branch_length  taxa_count  \
# 0                  0.019186                 0.014370        32.0
# 1                  0.049395                 0.016235        32.0
# 2                  0.013116                 0.002767        32.0
# 3                  0.031143                 0.024793        32.0
# 4                  0.047516                 0.018597        32.0
#
#    alignment_length  gap_fraction_global  gc_mean_global  gc_std_global  \
# 0            2142.0             0.312544        0.517434        0.03728
# 1            2142.0             0.312544        0.517434        0.03728
# 2            2142.0             0.312544        0.517434        0.03728
# 3            2142.0             0.312544        0.517434        0.03728
# 4            2142.0             0.312544        0.517434        0.03728
#
#    variable_site_fraction_global  gap_fraction_clade  gc_mean_clade  \
# 0                       0.830099            0.329115       0.521565
# 1                       0.830099            0.250233       0.498934
# 2                       0.830099            0.283253       0.512382
# 3                       0.830099            0.306291       0.513912
# 4                       0.830099            0.351940       0.529217
#
#    gc_std_clade  mean_pairwise_pdist_clade
# 0      0.036721                   0.363910
# 1      0.035370                   0.116415
# 2      0.036787                   0.250606
# 3      0.037339                   0.444156
# 4      0.034432                   0.215477

# %%
import pandas as pd
pd.DataFrame(audit)
# Out:
#    dataset_id                                     alignment_file  \
# 0         dt1  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 1        dt10  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 2        dt11  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 3        dt12  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 4        dt13  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 5        dt14  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 6        dt15  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 7        dt16  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 8        dt19  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 9         dt2  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 10       dt20  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 11        dt4  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 12        dt5  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 13        dt7  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
# 14        dt8  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...
#
#                                             tree_file     ok  \
# 0   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 1   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 2   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 3   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 4   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 5   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 6   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 7   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 8   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 9   c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 10  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 11  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...  False
# 12  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 13  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
# 14  c:\GitHubMain\GraduateWork\ml_outputs_v1\datas...   True
#
#                                    error  n_rows
# 0                                   None    29.0
# 1                                   None    90.0
# 2                                   None    37.0
# 3                                   None    18.0
# 4                                   None   103.0
# 5                                   None    54.0
# 6                                   None    42.0
# 7                                   None    41.0
# 8                                   None    51.0
# 9                                   None    62.0
# 10                                  None    65.0
# 11  В файле не найдено BEGIN CHARACTERS.     NaN
# 12                                  None    94.0
# 13                                  None    26.0
# 14                                  None    18.0

# %%
model, metrics, feature_importance, pred_df = train_model(df)

metrics

feature_importance.head(20)
# Out:
#                           feature  importance
# 0                   branch_length    0.527311
# 15                   gc_std_clade    0.116986
# 16      mean_pairwise_pdist_clade    0.053319
# 14                  gc_mean_clade    0.041828
# 5        mean_child_branch_length    0.038172
# 6         std_child_branch_length    0.035705
# 3                subtree_fraction    0.035388
# 2                n_leaves_subtree    0.033422
# 1                           depth    0.033071
# 13             gap_fraction_clade    0.027172
# 10                 gc_mean_global    0.017819
# 4                 subtree_balance    0.010127
# 11                  gc_std_global    0.009451
# 8                alignment_length    0.006289
# 9             gap_fraction_global    0.005541
# 12  variable_site_fraction_global    0.004447
# 7                      taxa_count    0.003953

# %%
import json
import joblib
import pandas as pd
from pathlib import Path

output_dir = Path.cwd() / "ml_outputs_v1"
output_dir.mkdir(exist_ok=True)

df.to_csv(output_dir / "node_dataset.csv", index=False, encoding="utf-8-sig")
pd.DataFrame(audit).to_csv(output_dir / "dataset_audit.csv", index=False, encoding="utf-8-sig")
feature_importance.to_csv(output_dir / "feature_importance.csv", index=False, encoding="utf-8-sig")
pred_df.to_csv(output_dir / "test_predictions.csv", index=False, encoding="utf-8-sig")
joblib.dump(model, output_dir / "model_v1.pkl")

with open(output_dir / "model_metadata.json", "w", encoding="utf-8") as f:
    json.dump(metrics, f, ensure_ascii=False, indent=2)

print("Сохранено в:", output_dir)
# Out:
# Сохранено в: c:\GitHubMain\GraduateWork\ml_outputs_v1\ml_outputs_v1

# %%
print("Всего строк:", len(df))
print("Уникальных datasets:", df["dataset_id"].nunique())
print("Колонки:")
print(df.columns.tolist())
# Out:
# Всего строк: 730
# Уникальных datasets: 14
# Колонки:
# ['dataset_id', 'node_id', 'target_bootstrap', 'branch_length', 'depth', 'n_leaves_subtree', 'subtree_fraction', 'subtree_balance', 'mean_child_branch_length', 'std_child_branch_length', 'taxa_count', 'alignment_length', 'gap_fraction_global', 'gc_mean_global', 'gc_std_global', 'variable_site_fraction_global', 'gap_fraction_clade', 'gc_mean_clade', 'gc_std_clade', 'mean_pairwise_pdist_clade']

# %%
df["target_bootstrap"].describe()
# Out:
# count    730.000000
# mean      65.689918
# std       31.809366
# min        1.330000
# 25%       38.000000
# 50%       69.500000
# 75%       99.000000
# max      100.000000
# Name: target_bootstrap, dtype: float64

# %%
metrics
# Out:
# {'n_rows_total': 730,
#  'n_rows_train': 519,
#  'n_rows_test': 211,
#  'n_datasets_total': 14,
#  'n_datasets_train': 10,
#  'n_datasets_test': 4,
#  'mae': 12.915857819905218,
#  'rmse': 17.209801594603398,
#  'r2': 0.6781877563138208,
#  'feature_columns': ['branch_length',
#   'depth',
#   'n_leaves_subtree',
#   'subtree_fraction',
#   'subtree_balance',
#   'mean_child_branch_length',
#   'std_child_branch_length',
#   'taxa_count',
#   'alignment_length',
#   'gap_fraction_global',
#   'gc_mean_global',
#   'gc_std_global',
#   'variable_site_fraction_global',
#   'gap_fraction_clade',
#   'gc_mean_clade',
#   'gc_std_clade',
#   'mean_pairwise_pdist_clade'],
#  'train_datasets': ['dt10',
#   'dt11',
#   'dt12',
#   'dt13',
#   'dt14',
#   'dt15',
#   'dt16',
#   'dt19',
#   'dt20',
#   'dt8'],
#  'test_datasets': ['dt1', 'dt2', 'dt5', 'dt7']}
